# %%
# !pip install beautifulsoup4

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from time import sleep
import csv
import json
import re

# %%
# file containing artists - songs mapping
songs_json = "Artists-Songs Mapping.json"
songs_dict = {}

with open(songs_json) as file:
    songs_dict = json.load(file)

# %%
# artist for which the lyrics need to be written
artist = "eminem"
songs = songs_dict[artist]
processed_songs = []

# preprocessing the songs name for scraping
for song in songs:
    numbers_in_brackets_removed = re.sub(r'\(.*\)',"",song)
    processed_song = re.sub(r'\W+', '', numbers_in_brackets_removed).lower()
    processed_songs.append(processed_song)
    
print(len(processed_songs))

# Removing duplicate songs
processed_songs = list(set(processed_songs))
print(len(processed_songs))
print(processed_songs[:20])

# import re

# # Initialize a list to hold all processed song names
# all_processed_songs = []

# # List of artists for which we need to process song names
# artists = ["edsheeran", "eminem", "taylorswift", "rihanna", "arianagrande", 
#            "coldplay", "lanadelrey", "maroon5", "michaeljackson", "onedirection"]

# for artist in artists:
#     # Get the list of songs for the current artist
#     songs = songs_dict.get(artist, [])
    
#     # Preprocess the songs name
#     processed_songs = []
#     for song in songs:
#         numbers_in_brackets_removed = re.sub(r'\(.*\)', "", song)
#         processed_song = re.sub(r'\W+', '', numbers_in_brackets_removed).lower()
#         processed_songs.append(processed_song)
    
#     # Add the processed songs to the main list
#     all_processed_songs.extend(processed_songs)

# # Remove duplicates from the final list
# unique_processed_songs = list(set(all_processed_songs))

# print(f"Total number of processed songs: {len(all_processed_songs)}")
# print(f"Number of unique processed songs: {len(unique_processed_songs)}")
# print("First 20 unique processed songs:", unique_processed_songs[:20])
# Out:
# 190
# 180
# ['legacy', 'oneshot2shotfeatd12', 'stilldontgiveafuck', 'asshole', 'cumoneverybody', 'wtp', 'beautiful', 'hegotgame', 'medicineball', 'skimaskway', 'mymom', 'sofar', 'yellowbrickroad', 'whenimgone', 'guiltyconsciencedrdreeminem', 'alikethat', 'rhymeorreason', 'myfault', 'drwest', 'hello']

# %%
# url to scrape the lyrics from
base_url = "https://www.azlyrics.com/lyrics/{}/{}.html"

# file in which the lyrics would be saved
lyrics_file = "lyrics_scraped.txt"

lyrics_not_found_for = []

# delay after each execution of call for not exceeding the requests count and also not to overburden the server
delay = 10

with open(lyrics_file, "w") as file:
    
    for song in processed_songs:
        final_url = base_url.format(artist,song)

        try:
            html_page = urlopen(final_url)
            soup = BeautifulSoup(html_page, 'html.parser')

            html_pointer = soup.find('div', attrs={'class':'ringtone'})
            song_name = html_pointer.find_next('b').contents[0].strip()
            lyrics = html_pointer.find_next('div').text.strip()

            file.write("###"+song_name+"###")
            file.write("\n\n")
            file.write(lyrics)
            file.write("\n\n")
            
            print("Lyrics successfully written to file for : " + song_name)
            
        except:
            print("Lyrics not found for : " + song) 
            lyrics_not_found_for.append(song)
            
        finally:
            sleep(delay)
# Out:
# Lyrics successfully written to file for : "Legacy"
# Lyrics not found for : oneshot2shotfeatd12
# Lyrics successfully written to file for : "Still Don't Give A Fuck"
# Lyrics successfully written to file for : "Asshole"
# Lyrics successfully written to file for : "Cum On Everybody"
# Lyrics successfully written to file for : "W.T.P."
# Lyrics successfully written to file for : "Beautiful"
# Lyrics not found for : hegotgame
# Lyrics successfully written to file for : "Medicine Ball"
# Lyrics not found for : skimaskway
# Lyrics successfully written to file for : "My Mom"
# Lyrics successfully written to file for : "So Far..."
# Lyrics successfully written to file for : "Yellow Brick Road"
# Lyrics successfully written to file for : "When I'm Gone"
# Lyrics not found for : guiltyconsciencedrdreeminem
# Lyrics not found for : alikethat
# Lyrics successfully written to file for : "Rhyme Or Reason"
# Lyrics successfully written to file for : "My Fault"
# Lyrics not found for : drwest
# Lyrics successfully written to file for : "Hello"
# Lyrics not found for : kenkaniff
# Lyrics not found for : paulrosenberg
# Lyrics not found for : publicserviceannouncement
# Lyrics successfully written to file for : "Underground"
# Lyrics successfully written to file for : "Hell Breaks Loose"
# Lyrics successfully written to file for : "Stan"
# Lyrics not found for : bpleaseii
# Lyrics not found for : dãjãvu
# Lyrics not found for : spendsometimefeatobietricestatquo50cent
# Lyrics successfully written to file for : "Cleanin Out My Closet"
# Lyrics successfully written to file for : "We As Americans"
# Lyrics not found for : realslimshady
# Lyrics not found for : werideforshady
# Lyrics successfully written to file for : "Almost Famous"
# Lyrics not found for : dropthebombon
# Lyrics successfully written to file for : "Just Lose It"
# Lyrics not found for : murder
# Lyrics successfully written to file for : "Trapped"
# Lyrics successfully written to file for : "When The Music Stops"
# Lyrics successfully written to file for : "Drug Ballad"
# Lyrics successfully written to file for : "My Dad's Gone Crazy"
# Lyrics successfully written to file for : "Desperation"
# Lyrics successfully written to file for : "Bad Guy"
# Lyrics not found for : my1stsingle
# Lyrics successfully written to file for : "Sing For The Moment"
# Lyrics successfully written to file for : "Puke"
# Lyrics successfully written to file for : "Square Dance"
# Lyrics successfully written to file for : "Marshall Mathers"
# Lyrics successfully written to file for : "Drips"
# Lyrics successfully written to file for : "Criminal"
# Lyrics not found for : smackthat
# Lyrics not found for : wayiam
# Lyrics successfully written to file for : "I'm Shady"
# Lyrics successfully written to file for : "You Don't Know"
# Lyrics successfully written to file for : "Evil Deeds"
# Lyrics not found for : whateveryouwant
# Lyrics successfully written to file for : "3 A.M."
# Lyrics not found for : pistolpistol
# Lyrics not found for : soap
# Lyrics successfully written to file for : "Ricky Ticky Toc"
# Lyrics successfully written to file for : "Buffalo Bill"
# Lyrics successfully written to file for : "Say Goodbye Hollywood"
# Lyrics not found for : talkinallthat
# Lyrics successfully written to file for : "Bitch Please II"
# Lyrics successfully written to file for : "Who Knew"
# Lyrics not found for : callmeslim
# Lyrics not found for : curtainsup
# Lyrics not found for : thekiss
# Lyrics successfully written to file for : "Love The Way You Lie"
# Lyrics not found for : forgotaboutdre
# Lyrics successfully written to file for : "Forever"
# Lyrics not found for : finalthought
# Lyrics successfully written to file for : "Untitled"
# Lyrics successfully written to file for : "Old Time's Sake"
# Lyrics successfully written to file for : "Music Box"
# Lyrics successfully written to file for : "Fack"
# Lyrics not found for : encorefeatdrdre50cent
# Lyrics not found for : baby
# Lyrics not found for : crazyinlove
# Lyrics not found for : emcallspaul
# Lyrics not found for : cinderellaman
# Lyrics not found for : saywhatyousay
# Lyrics not found for : wemadeyou
# Lyrics not found for : shakethatnatedoggeminem
# Lyrics not found for : themonster
# Lyrics not found for : bymyside
# Lyrics not found for : tonya
# Lyrics not found for : staywideawake
# Lyrics not found for : mosh
# Lyrics not found for : berzerk
# Lyrics not found for : darknessandillumination
# Lyrics not found for : kim

# %%
print("Total count : ", len(songs),"songs")
print("Lyrics successfully scraped for : ", len(songs)-len(lyrics_not_found_for), "songs")
print("Lyrics not found for :", len(lyrics_not_found_for),"songs\n")
print("\nHere's the list :\n")
print(lyrics_not_found_for)
# Out:
# Total count :  190 songs
# Lyrics successfully scraped for :  68 songs
# Lyrics not found for : 122 songs
#
#
# Here's the list :
#
# ['oneshot2shotfeatd12', 'hegotgame', 'skimaskway', 'guiltyconsciencedrdreeminem', 'alikethat', 'drwest', 'kenkaniff', 'paulrosenberg', 'publicserviceannouncement', 'bpleaseii', 'dãjãvu', 'spendsometimefeatobietricestatquo50cent', 'realslimshady', 'werideforshady', 'dropthebombon', 'murder', 'my1stsingle', 'smackthat', 'wayiam', 'whateveryouwant', 'pistolpistol', 'soap', 'talkinallthat', 'callmeslim', 'curtainsup', 'thekiss', 'forgotaboutdre', 'finalthought', 'lounge', 'parkinglot', 'thehiphopgenesis', 'psa2000', 'beautifulpain', 'neverenoughfeat50centnatedogg', 'tryintawin', 'braindamage', 'wickedways', 'tillicollapse', 'loveyoumore', 'crynow', 'youreneverover', 'themiseducationofmarshallmathers', 'publicserviceannouncement2000', 'survival', 'rockbottom', 'nolove', 'eviltwin', 'goingthroughchanges', 'undergroundkenkaniff', 'mustbetheganja', 'pleasestandup', 'amityville', 'coldwindblows', 'liketoysoldiers', 'everythingisshady', 'insane', 'soldier', 'superman', 'therebelcry', 'badmeetsevil', 'steveberman', 'mockingbird', 'wontbackdown', 'loseyourself', 'getlow', 'detroitrapcity', 'paul', 'thereheis', 'curtainsclose', 'rainman', 'samesongdance', 'ifihad', 'groundhogday', 'talkin2myself', 'sobad', '97bonnieclyde', 'astheworldturns', 'business', 'imback', 'elevator', 'mynameis', 'noapologies', 'undertheinfluence', 'onfire', 'stanliveeminemeltonjohn', 'takingmyball', 'jimmycrackcorn', 'mrmathers', 'wereback', 'thereup', 'rememberme', 'intro', 'withoutme', '25tolife', 'theyoungmarshall', 'brainless', 'publicenemy1', 'headlights', 'standidoeminem', 'hailiessong', 'somuchbetter', 'strongerthaniwas', 'shadynarcotics', 'justdontgiveafuck', 'killyou', 'shakethat', 'encorefeatdrdre50cent', 'baby', 'crazyinlove', 'emcallspaul', 'cinderellaman', 'saywhatyousay', 'wemadeyou', 'shakethatnatedoggeminem', 'themonster', 'bymyside', 'tonya', 'staywideawake', 'mosh', 'berzerk', 'darknessandillumination', 'kim']
