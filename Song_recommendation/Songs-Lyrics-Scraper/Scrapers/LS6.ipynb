# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from time import sleep
import csv
import json
import re

# %%
# file containing artists - songs mapping
songs_json = "Artists-Songs Mapping.json"
songs_dict = {}

with open(songs_json) as file:
    songs_dict = json.load(file)

# %%
# artist for which the lyrics need to be written
artist = "coldplay"
songs = songs_dict[artist]
processed_songs = []

# preprocessing the songs name for scraping
for song in songs:
    numbers_in_brackets_removed = re.sub(r'\(.*\)',"",song)
    processed_song = re.sub(r'\W+', '', numbers_in_brackets_removed).lower()
    processed_songs.append(processed_song)
    
print(len(processed_songs))

# Removing duplicate songs
processed_songs = list(set(processed_songs))
print(len(processed_songs))
print(processed_songs[:20])
# Out:
# 115
# 109
# ['squareone', 'warningsign', 'seeyousoon', 'sucharush', 'postcardsfromfaraway', 'weneverchange', 'awhisper', 'glassofwater', 'sparks', 'biggerstronger', 'shiver', 'fixyou', 'spies', 'lifeintechnicolor', 'loversinjapanreignoflove', 'daylight', 'hurtslikeheaven', 'miracles', 'prospektsmarchpoppyfields', 'kaleidoscope']

# %%
# url to scrape the lyrics from
base_url = "https://www.azlyrics.com/lyrics/{}/{}.html"

# file in which the lyrics would be saved
lyrics_file = "lyrics_scraped6.txt"

lyrics_not_found_for = []

# delay after each execution of call for not exceeding the requests count and also not to overburden the server
delay = 10

with open(lyrics_file, "w") as file:
    
    for song in processed_songs:
        final_url = base_url.format(artist,song)

        try:
            html_page = urlopen(final_url)
            soup = BeautifulSoup(html_page, 'html.parser')

            html_pointer = soup.find('div', attrs={'class':'ringtone'})
            song_name = html_pointer.find_next('b').contents[0].strip()
            lyrics = html_pointer.find_next('div').text.strip()

            file.write("###"+song_name+"###")
            file.write("\n\n")
            file.write(lyrics)
            file.write("\n\n")
            
            print("Lyrics successfully written to file for : " + song_name)
            
        except:
            print("Lyrics not found for : " + song) 
            lyrics_not_found_for.append(song)
            
        finally:
            sleep(delay)
# Out:
# Lyrics not found for : squareone
# Lyrics not found for : warningsign
# Lyrics not found for : seeyousoon
# Lyrics not found for : sucharush
# Lyrics not found for : postcardsfromfaraway
# Lyrics not found for : weneverchange
# Lyrics not found for : awhisper
# Lyrics not found for : glassofwater
# Lyrics not found for : sparks
# Lyrics not found for : biggerstronger
# Lyrics not found for : shiver
# Lyrics successfully written to file for : "Fix You"
# Lyrics successfully written to file for : "Spies"
# Lyrics not found for : lifeintechnicolor
# Lyrics successfully written to file for : "Lovers In Japan / Reign Of Love"
# Lyrics successfully written to file for : "Daylight"
# Lyrics successfully written to file for : "Hurts Like Heaven"
# Lyrics successfully written to file for : "Miracles"
# Lyrics successfully written to file for : "Prospekt's March / Poppyfields"
# Lyrics successfully written to file for : "Kaleidoscope"
# Lyrics successfully written to file for : "A L I E N S"
# Lyrics not found for : intermission1
# Lyrics successfully written to file for : "Easy To Please"
# Lyrics successfully written to file for : "Charlie Brown"
# Lyrics successfully written to file for : "Low"
# Lyrics successfully written to file for : "Twisted Logic"
# Lyrics not found for : mmix
# Lyrics successfully written to file for : "Paradise"
# Lyrics successfully written to file for : "True Love"
# Lyrics successfully written to file for : "Talk"
# Lyrics not found for : loversinjapan
# Lyrics successfully written to file for : "Hymn For The Weekend"
# Lyrics successfully written to file for : "One I Love"
# Lyrics successfully written to file for : "Ink"
# Lyrics not found for : brothersandsisters
# Lyrics successfully written to file for : "Hypnotised"
# Lyrics successfully written to file for : "A Rush Of Blood To The Head"
# Lyrics successfully written to file for : "A Message"
# Lyrics successfully written to file for : "Adventure Of A Lifetime"
# Lyrics not found for : openingcredits
# Lyrics successfully written to file for : "O"
# Lyrics successfully written to file for : "Don't Panic"
# Lyrics successfully written to file for : "Viva La Vida"
# Lyrics successfully written to file for : "The Scientist"
# Lyrics successfully written to file for : "Always In My Head"
# Lyrics successfully written to file for : "Parachutes"
# Lyrics successfully written to file for : "Army Of One"
# Lyrics successfully written to file for : "Moses"
# Lyrics successfully written to file for : "U.F.O."
# Lyrics successfully written to file for : "Cemeteries Of London"
# Lyrics successfully written to file for : "Only Superstition"
# Lyrics successfully written to file for : "Rainy Day"
# Lyrics successfully written to file for : "Magic"
# Lyrics not found for : myloxyloto
# Lyrics successfully written to file for : "Violet Hill"
# Lyrics successfully written to file for : "A Head Full Of Dreams"
# Lyrics successfully written to file for : "Lost!"
# Lyrics successfully written to file for : "All I Can Think About Is You"
# Lyrics successfully written to file for : "Green Eyes"
# Lyrics successfully written to file for : "Now My Feet Won't Touch The Ground"
# Lyrics not found for : don8217tletitbreakyourheart
# Lyrics successfully written to file for : "Speed Of Sound"
# Lyrics successfully written to file for : "God Put A Smile Upon Your Face"
# Lyrics successfully written to file for : "The World Turned Upside Down"
# Lyrics successfully written to file for : "Oceans"
# Lyrics successfully written to file for : "Fun"
# Lyrics not found for : intermission5
# Lyrics successfully written to file for : "Up In Flames"
# Lyrics successfully written to file for : "Everything's Not Lost"
# Lyrics not found for : live2012menuloops
# Lyrics successfully written to file for : "Midnight"
# Lyrics not found for : intermission2
# Lyrics successfully written to file for : "What If?"
# Lyrics successfully written to file for : "Swallowed In The Sea"
# Lyrics successfully written to file for : "A Sky Full Of Stars"
# Lyrics successfully written to file for : "Us Against The World"
# Lyrics successfully written to file for : "Life Is For Living"
# Lyrics successfully written to file for : "Major Minus"
# Lyrics successfully written to file for : "Clocks"
# Lyrics successfully written to file for : "Colour Spectrum"
# Lyrics successfully written to file for : "42"
# Lyrics successfully written to file for : "Strawberry Swing"
# Lyrics not found for : intermission4
# Lyrics successfully written to file for : "In My Place"
# Lyrics successfully written to file for : "Death And All His Friends"
# Lyrics successfully written to file for : "Princess Of China"
# Lyrics successfully written to file for : "White Shadows"
# Lyrics successfully written to file for : "Don't Let It Break Your Heart"
# Lyrics successfully written to file for : "Trouble"
# Lyrics successfully written to file for : "X&Y"
# Lyrics successfully written to file for : "Every Teardrop Is A Waterfall"
# Lyrics not found for : hardestpart
# Lyrics successfully written to file for : "Pour Me"
# Lyrics successfully written to file for : "Up With The Birds"
# Lyrics successfully written to file for : "Politik"
# Lyrics successfully written to file for : "High Speed"
# Lyrics successfully written to file for : "Life In Technicolor II"
# Lyrics not found for : end
# Lyrics not found for : somethingjustlikethis
# Lyrics successfully written to file for : "Amsterdam"
# Lyrics not found for : ahopefultransmission
# Lyrics successfully written to file for : "Yes"
# Lyrics not found for : intermission3
# Lyrics successfully written to file for : "Another's Arms"
# Lyrics successfully written to file for : "Amazing Day"
# Lyrics successfully written to file for : "Til Kingdom Come"
# Lyrics successfully written to file for : "Everglow"
# Lyrics successfully written to file for : "Up&Up"
# Lyrics successfully written to file for : "Yellow"

# %%
print("Total count : ", len(songs),"songs")
print("Lyrics successfully scraped for : ", len(songs)-len(lyrics_not_found_for), "songs")
print("Lyrics not found for :", len(lyrics_not_found_for),"songs\n")
print("\nHere's the list :\n")
print(lyrics_not_found_for)
# Out:
# Total count :  115 songs
# Lyrics successfully scraped for :  87 songs
# Lyrics not found for : 28 songs
#
#
# Here's the list :
#
# ['squareone', 'warningsign', 'seeyousoon', 'sucharush', 'postcardsfromfaraway', 'weneverchange', 'awhisper', 'glassofwater', 'sparks', 'biggerstronger', 'shiver', 'lifeintechnicolor', 'intermission1', 'mmix', 'loversinjapan', 'brothersandsisters', 'openingcredits', 'myloxyloto', 'don8217tletitbreakyourheart', 'intermission5', 'live2012menuloops', 'intermission2', 'intermission4', 'hardestpart', 'end', 'somethingjustlikethis', 'ahopefultransmission', 'intermission3']
