# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from time import sleep
import csv
import json
import re

# %%
# file containing artists - songs mapping
songs_json = "Artists-Songs Mapping.json"
songs_dict = {}

with open(songs_json) as file:
    songs_dict = json.load(file)

# %%
# artist for which the lyrics need to be written
artist = "michaeljackson"
songs = songs_dict[artist]
processed_songs = []

# preprocessing the songs name for scraping
for song in songs:
    numbers_in_brackets_removed = re.sub(r'\(.*\)',"",song)
    processed_song = re.sub(r'\W+', '', numbers_in_brackets_removed).lower()
    processed_songs.append(processed_song)
    
print(len(processed_songs))

# Removing duplicate songs
processed_songs = list(set(processed_songs))
print(len(processed_songs))
print(processed_songs[:20])
# Out:
# 298
# 276
# ['lovesgonebad', 'iwannabewhereyouaredallasaustinremix', 'willyoubethere', 'blameitontheboogiethejacksons', 'earthsong', 'lovingyou', 'allthethingsyouare', 'whoslookingforalover', 'thisplacehotelthejacksons', 'wevehadenough', 'getonthefloor', 'peoplemaketheworldgoround', 'justalittlebitofyou', 'healtheworld', 'mygirl', '2bad', 'itsthefallinginlove', 'dangerous', 'hereiam', 'girlfriend']

# %%
# url to scrape the lyrics from
base_url = "https://www.azlyrics.com/lyrics/{}/{}.html"

# file in which the lyrics would be saved
lyrics_file = "lyrics_scraped9.txt"

lyrics_not_found_for = []

# delay after each execution of call for not exceeding the requests count and also not to overburden the server
delay = 10

with open(lyrics_file, "w") as file:
    
    for song in processed_songs:
        final_url = base_url.format(artist,song)

        try:
            html_page = urlopen(final_url)
            soup = BeautifulSoup(html_page, 'html.parser')

            html_pointer = soup.find('div', attrs={'class':'ringtone'})
            song_name = html_pointer.find_next('b').contents[0].strip()
            lyrics = html_pointer.find_next('div').text.strip()

            file.write("###"+song_name+"###")
            file.write("\n\n")
            file.write(lyrics)
            file.write("\n\n")
            
            print("Lyrics successfully written to file for : " + song_name)
            
        except:
            print("Lyrics not found for : " + song) 
            lyrics_not_found_for.append(song)
            
        finally:
            sleep(delay)
# Out:
# Lyrics not found for : lovesgonebad
# Lyrics not found for : iwannabewhereyouaredallasaustinremix
# Lyrics successfully written to file for : "Will You Be There"
# Lyrics not found for : blameitontheboogiethejacksons
# Lyrics successfully written to file for : "Earth Song"
# Lyrics successfully written to file for : "Loving You"
# Lyrics successfully written to file for : "All The Things You Are"
# Lyrics not found for : whoslookingforalover
# Lyrics not found for : thisplacehotelthejacksons
# Lyrics successfully written to file for : "We've Had Enough"
# Lyrics successfully written to file for : "Get On The Floor"
# Lyrics successfully written to file for : "People Make The World Go Round"
# Lyrics successfully written to file for : "Just A Little Bit Of You"
# Lyrics successfully written to file for : "Heal The World"
# Lyrics successfully written to file for : "My Girl"
# Lyrics successfully written to file for : "2 Bad"
# Lyrics successfully written to file for : "It's The Falling In Love"
# Lyrics successfully written to file for : "Dangerous"
# Lyrics not found for : hereiam
# Lyrics successfully written to file for : "Girlfriend"
# Lyrics successfully written to file for : "You Can Cry On My Shoulder"
# Lyrics not found for : isitscarythreatened
# Lyrics not found for : dancingmachine
# Lyrics successfully written to file for : "Don't Walk Away"
# Lyrics not found for : beatitstateofshock
# Lyrics not found for : bloodonthedancefloorxdangerousthewhitepandamash
# Lyrics not found for : dancingmachinesteveaokiremix
# Lyrics not found for : givemehalfachance
# Lyrics not found for : sunsetdriverdemo
# Lyrics successfully written to file for : "You Are There"
# Lyrics successfully written to file for : "Everybody's Somebody's Fool"
# Lyrics not found for : maybetomorrowsturkenrogersremix
# Lyrics successfully written to file for : "With A Child's Heart"
# Lyrics successfully written to file for : "Rock With You"
# Lyrics not found for : vincentprice
# Lyrics successfully written to file for : "Don't Stop 'Til You Get Enough"
# Lyrics not found for : healingtheworld
# Lyrics not found for : planetearthearthsong
# Lyrics successfully written to file for : "Beautiful Girl"
# Lyrics successfully written to file for : "Can't Let Her Get Away"
# Lyrics successfully written to file for : "Love Never Felt So Good"
# Lyrics successfully written to file for : "Beat It"
# Lyrics successfully written to file for : "You Rock My World"
# Lyrics not found for : theloveyousave
# Lyrics successfully written to file for : "Ghosts"
# Lyrics not found for : motowncalling
# Lyrics successfully written to file for : "You Can't Win"
# Lyrics not found for : dancingmachinesingleversion
# Lyrics not found for : interviewwithquincyjonesandrodtemperton
# Lyrics successfully written to file for : "Leave Me Alone"
# Lyrics not found for : nevercansaygoodbyetheneptunesremix
# Lyrics not found for : nevercansaygoodbyethejackson5
# Lyrics successfully written to file for : "Scared Of The Moon"
# Lyrics not found for : youarenotaloneijustcantstoplovingyou
# Lyrics successfully written to file for : "Black Or White"
# Lyrics successfully written to file for : "Dear Michael"
# Lyrics not found for : workindayandnight
# Lyrics not found for : wearetheworld
# Lyrics not found for : itstoolatetochangethetimethejackson5
# Lyrics successfully written to file for : "We Are Here To Change The World"
# Lyrics not found for : lonelyteardrops
# Lyrics not found for : billiejean2008withkanyewest
# Lyrics successfully written to file for : "I Just Can't Stop Loving You"
# Lyrics not found for : greatestshowonearth
# Lyrics not found for : pyt2008withmichaeljacksonandwilliampreviouslyunreleasedtrackfo
# Lyrics not found for : whoslovinyoujackson5
# Lyrics not found for : maybetomorrowthejackson5
# Lyrics not found for : stateofshockthejacksons
# Lyrics not found for : thatswhatloveismadeof
# Lyrics not found for : ifniwasagod
# Lyrics successfully written to file for : "She Drives Me Wild"
# Lyrics not found for : loveneverfeltsogoodmichaeljacksonjustintimberlake
# Lyrics successfully written to file for : "You've Really Got A Hold On Me"
# Lyrics not found for : rememberthetimebad
# Lyrics successfully written to file for : "Too Young"
# Lyrics successfully written to file for : "Carousel"
# Lyrics successfully written to file for : "Monster"
# Lyrics not found for : mariaemilehaynieremix
# Lyrics not found for : abc
# Lyrics successfully written to file for : "Blood On The Dance Floor"
# Lyrics successfully written to file for : "In The Back"
# Lyrics not found for : rockinrobinthejackson5
# Lyrics successfully written to file for : "Chicago"
# Lyrics successfully written to file for : "The Lost Children"
# Lyrics not found for : theloveyousavethejackson5
# Lyrics not found for : burnthisdiscoout
# Lyrics successfully written to file for : "Fly Away"
# Lyrics successfully written to file for : "Touch The One You Love"
# Lyrics successfully written to file for : "I Can't Help It"
# Lyrics successfully written to file for : "Who Is It"
# Lyrics successfully written to file for : "Wings Of My Love"
# Lyrics not found for : humalongdancedavidmoralesremix
# Lyrics successfully written to file for : "Scream"
# Lyrics successfully written to file for : "Heartbreaker"
# Lyrics successfully written to file for : "Little Susie"
# Lyrics successfully written to file for : "She's Out Of My Life"
# Lyrics successfully written to file for : "Heaven Can Wait"
# Lyrics successfully written to file for : "They Don't Care About Us"
# Lyrics successfully written to file for : "D.S."
# Lyrics successfully written to file for : "Fall Again"
# Lyrics not found for : whoslookinforalover
# Lyrics successfully written to file for : "Ain't No Sunshine"
# Lyrics not found for : afoolforyoujackson5
# Lyrics successfully written to file for : "You Are Not Alone"
# Lyrics not found for : iwantyouback
# Lyrics not found for : forevercametoday
# Lyrics not found for : screamlouder
# Lyrics not found for : superstar
# Lyrics not found for : ilikeyouthewayyouare
# Lyrics successfully written to file for : "Jam"
# Lyrics successfully written to file for : "Streetwalker"
# Lyrics successfully written to file for : "You Are My Life"
# Lyrics not found for : shakeyourbody
# Lyrics not found for : dancingmachineblameitontheboogie
# Lyrics not found for : interviewrodtempertonquincyjones
# Lyrics successfully written to file for : "Johnny Raven"
# Lyrics successfully written to file for : "Take Me Back"
# Lyrics not found for : wannabestartinsomethin2008withmichaeljacksonakonandwilliampreviouslyunreleasedtra
# Lyrics successfully written to file for : "One Day In Your Life"
# Lyrics not found for : speechlesshumannature
# Lyrics successfully written to file for : "Xscape"
# Lyrics successfully written to file for : "Girl You're So Together"
# Lyrics successfully written to file for : "We're Almost There"
# Lyrics successfully written to file for : "Dirty Diana"
# Lyrics successfully written to file for : "Hollywood Tonight"
# Lyrics not found for : ihearasymphony
# Lyrics successfully written to file for : "Smooth Criminal"
# Lyrics successfully written to file for : "This Time Around"
# Lyrics not found for : workingdayandnightlivevideo
# Lyrics successfully written to file for : "On The Line"
# Lyrics successfully written to file for : "Keep The Faith"
# Lyrics successfully written to file for : "Superfly Sister"
# Lyrics not found for : illbetherelivevideo
# Lyrics successfully written to file for : "Happy"
# Lyrics successfully written to file for : "In The Closet"
# Lyrics successfully written to file for : "The Way You Make Me Feel"
# Lyrics successfully written to file for : "Another Part Of Me"
# Lyrics successfully written to file for : "Speed Demon"
# Lyrics successfully written to file for : "Money"
# Lyrics not found for : immortalmegamixcanyoufeelitdontstoptilyougetenoughbilliejeanblackorwhiteimmortal
# Lyrics successfully written to file for : "Speechless"
# Lyrics successfully written to file for : "Threatened"
# Lyrics not found for : somebodyswatchingmerockwell
# Lyrics successfully written to file for : "Working Day And Night"
# Lyrics successfully written to file for : "2000 Watts"
# Lyrics successfully written to file for : "To Make My Father Proud"
# Lyrics not found for : dancingmachinepolowremix
# Lyrics successfully written to file for : "Blue Gangsta"
# Lyrics successfully written to file for : "Human Nature"
# Lyrics successfully written to file for : "Whatever Happens"
# Lyrics successfully written to file for : "Why You Wanna Trip On Me"
# Lyrics not found for : introtoflyaway
# Lyrics successfully written to file for : "Much Too Soon"
# Lyrics successfully written to file for : "Just Good Friends"
# Lyrics successfully written to file for : "Stranger In Moscow"
# Lyrics not found for : newdimension
# Lyrics not found for : easeondowntheroad
# Lyrics successfully written to file for : "Call On Me"
# Lyrics successfully written to file for : "Monkey Business"
# Lyrics not found for : pyt
# Lyrics successfully written to file for : "Childhood"
# Lyrics not found for : benakon
# Lyrics not found for : thegirlismine2008withwilliam
# Lyrics successfully written to file for : "Is It Scary?"
# Lyrics successfully written to file for : "Man In The Mirror"
# Lyrics successfully written to file for : "Give In To Me"
# Lyrics not found for : iwantyoubacklivevideo
# Lyrics not found for : teenagesymphony
# Lyrics not found for : you
# Lyrics successfully written to file for : "HIStory"
# Lyrics not found for : illbethere
# Lyrics not found for : ifniwasgod
# Lyrics successfully written to file for : "Thriller"
# Lyrics successfully written to file for : "I Wanna Be Where You Are"
# Lyrics successfully written to file for : "We've Got Forever"
# Lyrics not found for : wantyouback
# Lyrics not found for : dancingmachinethejackson5
# Lyrics successfully written to file for : "Farewell My Summer Love"
# Lyrics successfully written to file for : "Got To Be There"
# Lyrics not found for : iwasmadetoloveher
# Lyrics not found for : aintnosunshinebennyblancoremix
# Lyrics successfully written to file for : "Butterflies"
# Lyrics not found for : maria
# Lyrics not found for : gottobetherethejackson5
# Lyrics not found for : nevercansaygoodbye
# Lyrics successfully written to file for : "Someone Put Your Hand Out"
# Lyrics not found for : anotherday
# Lyrics successfully written to file for : "Liberian Girl"
# Lyrics successfully written to file for : "Smile"
# Lyrics not found for : enjoyyourselfthejacksons
# Lyrics not found for : interviewquincyjones
# Lyrics not found for : youremybestfriendmylove
# Lyrics successfully written to file for : "Wanna Be Startin' Somethin'"
# Lyrics not found for : screamlittlesusie
# Lyrics successfully written to file for : "Best Of Joy"
# Lyrics not found for : personaltouch
# Lyrics successfully written to file for : "Keep Your Head Up"
# Lyrics successfully written to file for : "A Place With No Name"
# Lyrics not found for : darlingdear
# Lyrics successfully written to file for : "Up Again"
# Lyrics successfully written to file for : "What Goes Around Comes Around"
# Lyrics successfully written to file for : "Melodie"
# Lyrics successfully written to file for : "Break Of Dawn"
# Lyrics not found for : dreamscometrue
# Lyrics not found for : thejackson5medley
# Lyrics successfully written to file for : "I'll Come Home To You"
# Lyrics successfully written to file for : "In Our Small Way"
# Lyrics successfully written to file for : "Behind The Mask"
# Lyrics successfully written to file for : "Girl Don't Take Your Love From Me"
# Lyrics successfully written to file for : "Ben"
# Lyrics successfully written to file for : "Cheater"
# Lyrics successfully written to file for : "Dapper Dan"
# Lyrics not found for : walkingonthemoon
# Lyrics successfully written to file for : "One More Chance"
# Lyrics not found for : itstoolatetochangethetime
# Lyrics successfully written to file for : "Come Together"
# Lyrics not found for : neverland
# Lyrics successfully written to file for : "Invincible"
# Lyrics successfully written to file for : "Off The Wall"
# Lyrics not found for : iwantyoubackthejackson5
# Lyrics not found for : lovelyonethejacksons
# Lyrics successfully written to file for : "The Lady In My Life"
# Lyrics not found for : maybetomorrowjackson5
# Lyrics successfully written to file for : "You've Got A Friend"
# Lyrics not found for : foralltimepreviouslyunreleasedtrackfor
# Lyrics not found for : whenicomeofage
# Lyrics not found for : modernman
# Lyrics successfully written to file for : "Do You Know Where Your Children Are"
# Lyrics successfully written to file for : "Someone In The Dark"
# Lyrics successfully written to file for : "Euphoria"
# Lyrics successfully written to file for : "Love Is Here And Now You're Gone"
# Lyrics not found for : maketonightallmine
# Lyrics successfully written to file for : "Billie Jean"
# Lyrics successfully written to file for : "Baby Be Mine"
# Lyrics not found for : epic
# Lyrics successfully written to file for : "Breaking News"
# Lyrics not found for : musicandme
# Lyrics successfully written to file for : "The Girl Is Mine"
# Lyrics successfully written to file for : "Privacy"
# Lyrics successfully written to file for : "Cry"
# Lyrics successfully written to file for : "Hold My Hand"
# Lyrics not found for : ifidontloveyouthisway
# Lyrics not found for : planetearth
# Lyrics not found for : torturethejacksons
# Lyrics not found for : whoslovinyou
# Lyrics successfully written to file for : "Remember The Time"
# Lyrics successfully written to file for : "Morphine"
# Lyrics successfully written to file for : "Rockin' Robin"
# Lyrics not found for : childstar
# Lyrics successfully written to file for : "Gone Too Soon"
# Lyrics not found for : theimmortalintro
# Lyrics not found for : illbetherethejackson5
# Lyrics successfully written to file for : "This Is It"
# Lyrics not found for : twentyfivemiles
# Lyrics not found for : beatit2008withfergie
# Lyrics successfully written to file for : "Don't Let It Get You Down"
# Lyrics not found for : youregoodforme
# Lyrics not found for : voiceoversessionfromthriller
# Lyrics not found for : illbethereminusmix
# Lyrics not found for : whoslovingyou
# Lyrics not found for : thisplacehotel
# Lyrics not found for : skywriterstargateremix
# Lyrics successfully written to file for : "Bad"
# Lyrics successfully written to file for : "Doggin' Around"
# Lyrics successfully written to file for : "We've Got A Good Thing Going"
# Lyrics not found for : abcthejackson5
# Lyrics successfully written to file for : "Cinderella Stay Awhile"
# Lyrics successfully written to file for : "The Way You Love Me"
# Lyrics successfully written to file for : "Morning Glow"
# Lyrics successfully written to file for : "Slave To The Rhythm"
# Lyrics successfully written to file for : "Tabloid Junkie"
# Lyrics successfully written to file for : "Unbreakable"
# Lyrics not found for : maybetomorrow
# Lyrics not found for : themimesegmentthewayyoulovemespeeddemonanotherpartofme
# Lyrics not found for : kingofpop
# Lyrics successfully written to file for : "Shoo-Be-Doo-Be-Doo-Da-Day"

# %%
print("Total count : ", len(songs),"songs")
print("Lyrics successfully scraped for : ", len(songs)-len(lyrics_not_found_for), "songs")
print("Lyrics not found for :", len(lyrics_not_found_for),"songs\n")
print("\nHere's the list :\n")
print(lyrics_not_found_for)
# Out:
# Total count :  298 songs
# Lyrics successfully scraped for :  178 songs
# Lyrics not found for : 120 songs
#
#
# Here's the list :
#
# ['lovesgonebad', 'iwannabewhereyouaredallasaustinremix', 'blameitontheboogiethejacksons', 'whoslookingforalover', 'thisplacehotelthejacksons', 'hereiam', 'isitscarythreatened', 'dancingmachine', 'beatitstateofshock', 'bloodonthedancefloorxdangerousthewhitepandamash', 'dancingmachinesteveaokiremix', 'givemehalfachance', 'sunsetdriverdemo', 'maybetomorrowsturkenrogersremix', 'vincentprice', 'healingtheworld', 'planetearthearthsong', 'theloveyousave', 'motowncalling', 'dancingmachinesingleversion', 'interviewwithquincyjonesandrodtemperton', 'nevercansaygoodbyetheneptunesremix', 'nevercansaygoodbyethejackson5', 'youarenotaloneijustcantstoplovingyou', 'workindayandnight', 'wearetheworld', 'itstoolatetochangethetimethejackson5', 'lonelyteardrops', 'billiejean2008withkanyewest', 'greatestshowonearth', 'pyt2008withmichaeljacksonandwilliampreviouslyunreleasedtrackfo', 'whoslovinyoujackson5', 'maybetomorrowthejackson5', 'stateofshockthejacksons', 'thatswhatloveismadeof', 'ifniwasagod', 'loveneverfeltsogoodmichaeljacksonjustintimberlake', 'rememberthetimebad', 'mariaemilehaynieremix', 'abc', 'rockinrobinthejackson5', 'theloveyousavethejackson5', 'burnthisdiscoout', 'humalongdancedavidmoralesremix', 'whoslookinforalover', 'afoolforyoujackson5', 'iwantyouback', 'forevercametoday', 'screamlouder', 'superstar', 'ilikeyouthewayyouare', 'shakeyourbody', 'dancingmachineblameitontheboogie', 'interviewrodtempertonquincyjones', 'wannabestartinsomethin2008withmichaeljacksonakonandwilliampreviouslyunreleasedtra', 'speechlesshumannature', 'ihearasymphony', 'workingdayandnightlivevideo', 'illbetherelivevideo', 'immortalmegamixcanyoufeelitdontstoptilyougetenoughbilliejeanblackorwhiteimmortal', 'somebodyswatchingmerockwell', 'dancingmachinepolowremix', 'introtoflyaway', 'newdimension', 'easeondowntheroad', 'pyt', 'benakon', 'thegirlismine2008withwilliam', 'iwantyoubacklivevideo', 'teenagesymphony', 'you', 'illbethere', 'ifniwasgod', 'wantyouback', 'dancingmachinethejackson5', 'iwasmadetoloveher', 'aintnosunshinebennyblancoremix', 'maria', 'gottobetherethejackson5', 'nevercansaygoodbye', 'anotherday', 'enjoyyourselfthejacksons', 'interviewquincyjones', 'youremybestfriendmylove', 'screamlittlesusie', 'personaltouch', 'darlingdear', 'dreamscometrue', 'thejackson5medley', 'walkingonthemoon', 'itstoolatetochangethetime', 'neverland', 'iwantyoubackthejackson5', 'lovelyonethejacksons', 'maybetomorrowjackson5', 'foralltimepreviouslyunreleasedtrackfor', 'whenicomeofage', 'modernman', 'maketonightallmine', 'epic', 'musicandme', 'ifidontloveyouthisway', 'planetearth', 'torturethejacksons', 'whoslovinyou', 'childstar', 'theimmortalintro', 'illbetherethejackson5', 'twentyfivemiles', 'beatit2008withfergie', 'youregoodforme', 'voiceoversessionfromthriller', 'illbethereminusmix', 'whoslovingyou', 'thisplacehotel', 'skywriterstargateremix', 'abcthejackson5', 'maybetomorrow', 'themimesegmentthewayyoulovemespeeddemonanotherpartofme', 'kingofpop']
