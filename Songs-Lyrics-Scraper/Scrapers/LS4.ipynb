# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from time import sleep
import csv
import json
import re

# %%
# file containing artists - songs mapping
songs_json = "Artists-Songs Mapping.json"
songs_dict = {}

with open(songs_json) as file:
    songs_dict = json.load(file)

# %%
# artist for which the lyrics need to be written
artist = "rihanna"
songs = songs_dict[artist]
processed_songs = []

# preprocessing the songs name for scraping
for song in songs:
    numbers_in_brackets_removed = re.sub(r'\(.*\)',"",song)
    processed_song = re.sub(r'\W+', '', numbers_in_brackets_removed).lower()
    processed_songs.append(processed_song)
    
print(len(processed_songs))

# Removing duplicate songs
processed_songs = list(set(processed_songs))
print(len(processed_songs))
print(processed_songs[:20])
# Out:
# 99
# 91
# ['stay', 'fading', 'birthdaycake', 'breakindishes', 'theresathuginmylife', 'rightnow', 'shutupanddrive', 'whatsmyname', 'onlygirl', 'getitoverwith', 'agirllikeme', 'takeabow', 'rush', 'goodgirlgonebad', 'lovethewayyoulie', 'willingtowait', 'farewell', 'thatlalala', 'kissesdontlie', 'g4l']

# %%
# url to scrape the lyrics from
base_url = "https://www.azlyrics.com/lyrics/{}/{}.html"

# file in which the lyrics would be saved
lyrics_file = "lyrics_scraped4.txt"

lyrics_not_found_for = []

# delay after each execution of call for not exceeding the requests count and also not to overburden the server
delay = 10

with open(lyrics_file, "w") as file:
    
    for song in processed_songs:
        final_url = base_url.format(artist,song)

        try:
            html_page = urlopen(final_url)
            soup = BeautifulSoup(html_page, 'html.parser')

            html_pointer = soup.find('div', attrs={'class':'ringtone'})
            song_name = html_pointer.find_next('b').contents[0].strip()
            lyrics = html_pointer.find_next('div').text.strip()

            file.write("###"+song_name+"###")
            file.write("\n\n")
            file.write(lyrics)
            file.write("\n\n")
            
            print("Lyrics successfully written to file for : " + song_name)
            
        except:
            print("Lyrics not found for : " + song) 
            lyrics_not_found_for.append(song)
            
        finally:
            sleep(delay)
# Out:
# Lyrics successfully written to file for : "Stay"
# Lyrics successfully written to file for : "Fading"
# Lyrics successfully written to file for : "Birthday Cake"
# Lyrics successfully written to file for : "Breakin' Dishes"
# Lyrics successfully written to file for : "There's A Thug In My Life"
# Lyrics successfully written to file for : "Right Now"
# Lyrics successfully written to file for : "Shut Up And Drive"
# Lyrics successfully written to file for : "What's My Name?"
# Lyrics not found for : onlygirl
# Lyrics successfully written to file for : "Get It Over With"
# Lyrics successfully written to file for : "A Girl Like Me"
# Lyrics successfully written to file for : "Take A Bow"
# Lyrics successfully written to file for : "Rush"
# Lyrics successfully written to file for : "Good Girl Gone Bad"
# Lyrics not found for : lovethewayyoulie
# Lyrics successfully written to file for : "Willing To Wait"
# Lyrics successfully written to file for : "Farewell"
# Lyrics successfully written to file for : "That La, La, La"
# Lyrics successfully written to file for : "Kisses Don't Lie"
# Lyrics successfully written to file for : "G4L"
# Lyrics successfully written to file for : "Love Without Tragedy / Mother Mary"
# Lyrics successfully written to file for : "The Last Song"
# Lyrics successfully written to file for : "Rude Boy"
# Lyrics successfully written to file for : "You Da One"
# Lyrics successfully written to file for : "Lemme Get That"
# Lyrics successfully written to file for : "Here I Go Again"
# Lyrics successfully written to file for : "Rehab"
# Lyrics successfully written to file for : "Pon De Replay"
# Lyrics successfully written to file for : "We Found Love"
# Lyrics successfully written to file for : "Final Goodbye"
# Lyrics successfully written to file for : "Lost In Paradise"
# Lyrics successfully written to file for : "Numb"
# Lyrics successfully written to file for : "Mad House"
# Lyrics successfully written to file for : "Wait Your Turn"
# Lyrics successfully written to file for : "Pour It Up"
# Lyrics successfully written to file for : "Cold Case Love"
# Lyrics successfully written to file for : "Music Of The Sun"
# Lyrics successfully written to file for : "We All Want Love"
# Lyrics successfully written to file for : "Complicated"
# Lyrics not found for : ifineverseeyourfaceagainmaroon5
# Lyrics successfully written to file for : "Drunk On Love"
# Lyrics successfully written to file for : "Russian Roulette"
# Lyrics successfully written to file for : "Question Existing"
# Lyrics not found for : cheers
# Lyrics successfully written to file for : "Photographs"
# Lyrics successfully written to file for : "Loveeeeeee Song"
# Lyrics successfully written to file for : "Stupid In Love"
# Lyrics successfully written to file for : "Rockstar 101"
# Lyrics successfully written to file for : "The Last Time"
# Lyrics successfully written to file for : "Fire Bomb"
# Lyrics not found for : youdontloveme
# Lyrics successfully written to file for : "Jump"
# Lyrics successfully written to file for : "Raining Men"
# Lyrics successfully written to file for : "Disturbia"
# Lyrics successfully written to file for : "Selfish Girl"
# Lyrics successfully written to file for : "Talk That Talk"
# Lyrics not found for : ps
# Lyrics successfully written to file for : "Where Have You Been"
# Lyrics successfully written to file for : "Say It"
# Lyrics successfully written to file for : "Unfaithful"
# Lyrics successfully written to file for : "Fool In Love"
# Lyrics successfully written to file for : "Red Lipstick"
# Lyrics successfully written to file for : "Umbrella"
# Lyrics successfully written to file for : "Dem Haters"
# Lyrics successfully written to file for : "Push Up On Me"
# Lyrics successfully written to file for : "Hard"
# Lyrics successfully written to file for : "Diamonds"
# Lyrics successfully written to file for : "We Ride"
# Lyrics not found for : freshouttherunway
# Lyrics successfully written to file for : "Hate That I Love You"
# Lyrics successfully written to file for : "Do Ya Thang"
# Lyrics successfully written to file for : "A Million Miles Away"
# Lyrics successfully written to file for : "Now I Know"
# Lyrics successfully written to file for : "Sell Me Candy"
# Lyrics successfully written to file for : "Te Amo"
# Lyrics successfully written to file for : "California King Bed"
# Lyrics successfully written to file for : "Don't Stop The Music"
# Lyrics successfully written to file for : "Skin"
# Lyrics not found for : nobodiesbusiness
# Lyrics successfully written to file for : "No Love Allowed"
# Lyrics successfully written to file for : "Man Down"
# Lyrics successfully written to file for : "Crazy Little Thing Called Love"
# Lyrics successfully written to file for : "S&M"
# Lyrics not found for : sos
# Lyrics successfully written to file for : "Break It Off"
# Lyrics not found for : cockiness
# Lyrics successfully written to file for : "If It's Lovin' That You Want"
# Lyrics successfully written to file for : "Watch N' Learn"
# Lyrics successfully written to file for : "Roc Me Out"
# Lyrics successfully written to file for : "What Now"
# Lyrics successfully written to file for : "Let Me"

# %%
print("Total count : ", len(songs),"songs")
print("Lyrics successfully scraped for : ", len(songs)-len(lyrics_not_found_for), "songs")
print("Lyrics not found for :", len(lyrics_not_found_for),"songs\n")
print("\nHere's the list :\n")
print(lyrics_not_found_for)
# Out:
# Total count :  99 songs
# Lyrics successfully scraped for :  89 songs
# Lyrics not found for : 10 songs
#
#
# Here's the list :
#
# ['onlygirl', 'lovethewayyoulie', 'ifineverseeyourfaceagainmaroon5', 'cheers', 'youdontloveme', 'ps', 'freshouttherunway', 'nobodiesbusiness', 'sos', 'cockiness']
