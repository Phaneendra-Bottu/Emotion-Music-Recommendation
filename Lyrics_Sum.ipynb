# %%
import pandas as pd
from transformers import pipeline, AutoTokenizer

# Load the summarization model and tokenizer
model_name = "facebook/bart-large-cnn"
summarizer = pipeline("summarization", model=model_name, framework="pt")
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load the original CSV file
df = pd.read_csv("lyrics_CSV.csv")  # Replace 'lyrics_CSV.csv' with your CSV file path

# Define the summarization function
def summarize_lyrics(lyrics, song_name):
    if pd.isna(lyrics) or not lyrics.strip():  # Check for NaN or empty lyrics
        print(f"{song_name} lyrics are empty or NaN, added directly.")
        return lyrics
    
    # Tokenize the lyrics
    tokens = tokenizer(lyrics, return_tensors='pt', truncation=False)["input_ids"][0]
    token_count = len(tokens)

    # If initial tokens are less than 512, return the original lyrics
    if token_count < 512:
        print(f"{song_name} lyrics are less than 512 tokens, added directly.")
        return lyrics
    
    # If token count exceeds 1024, truncate before summarization
    if token_count > 1024:
        tokens = tokens[:1024]  # Keep only the first 1024 tokens
        lyrics = tokenizer.decode(tokens, skip_special_tokens=True)
        print(f"{song_name} lyrics truncated to 1024 tokens.")

    # Summarize the lyrics
    try:
        summary = summarizer(lyrics, max_length=512, min_length=0, do_sample=False)
        print(f"{song_name} lyrics summarized")
        return summary[0]['summary_text']
    except Exception as e:
        print(f"Error summarizing {song_name}: {e}")
        return lyrics  # Return original lyrics if there's an error

# Initialize a counter for song names
for idx, row in df.iterrows():
    df.at[idx, 'Summarized_Lyrics'] = summarize_lyrics(row['Lyrics'], row['Song Name'])

# Save the dataframe with summarized lyrics to a new CSV file
df.to_csv("Lyrics_Sum.csv", index=False)
# Out:
# Legacy lyrics summarized
# Token indices sequence length is longer than the specified maximum sequence length for this model (1293 > 1024). Running this sequence through the model will result in indexing errors
# Still Don't Give A Fuck lyrics summarized
# Asshole lyrics truncated to 1024 tokens.
# Asshole lyrics summarized
# Token indices sequence length is longer than the specified maximum sequence length for this model (1025 > 1024). Running this sequence through the model will result in indexing errors
# Cum On Everybody lyrics summarized
# W.T.P. lyrics truncated to 1024 tokens.
# Error summarizing W.T.P.: index out of range in self
# Beautiful lyrics truncated to 1024 tokens.
# Error summarizing Beautiful: index out of range in self
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 44
#      42 # Initialize a counter for song names
#      43 for idx, row in df.iterrows():
# ---> 44     df.at[idx, 'Summarized_Lyrics'] = summarize_lyrics(row['Lyrics'], row['Song Name'])
#      46 # Save the dataframe with summarized lyrics to a new CSV file
#      47 df.to_csv("Lyrics_Sum.csv", index=False)
#
# Cell In[4], line 35, in summarize_lyrics(lyrics, song_name)
#      33 # Summarize the lyrics
#      34 try:
# ---> 35     summary = summarizer(lyrics, max_length=512, min_length=0, do_sample=False)
#      36     print(f"{song_name} lyrics summarized")
#      37     return summary[0]['summary_text']
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\text2text_generation.py:265, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     241 def __call__(self, *args, **kwargs):
#     242     r"""
#     243     Summarize the text(s) given as inputs.
#     244
#    (...)
#     263           ids of the summary.
#     264     """
# --> 265     return super().__call__(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\text2text_generation.py:165, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     136 def __call__(self, *args, **kwargs):
#     137     r"""
#     138     Generate the output text(s) using text(s) given as inputs.
#     139
#    (...)
#     162           ids of the generated text.
#     163     """
# --> 165     result = super().__call__(*args, **kwargs)
#     166     if (
#     167         isinstance(args[0], list)
#     168         and all(isinstance(el, str) for el in args[0])
#     169         and all(len(res) == 1 for res in result)
#     170     ):
#     171         return [res[0] for res in result]
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1129, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1121     return next(
#    1122         iter(
#    1123             self.get_iterator(
#    (...)
#    1126         )
#    1127     )
#    1128 else:
# -> 1129     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1136, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1134 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1135     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1136     model_outputs = self.forward(model_inputs, **forward_params)
#    1137     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1138     return outputs
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1035, in Pipeline.forward(self, model_inputs, **forward_params)
#    1033     with inference_context():
#    1034         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1035         model_outputs = self._forward(model_inputs, **forward_params)
#    1036         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1037 else:
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\text2text_generation.py:187, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     185 generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     186 self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 187 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     188 out_b = output_ids.shape[0]
#     189 if self.framework == "pt":
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\generation\utils.py:1675, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1668     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1669         input_ids=input_ids,
#    1670         expand_size=generation_config.num_beams,
#    1671         is_encoder_decoder=self.config.is_encoder_decoder,
#    1672         **model_kwargs,
#    1673     )
#    1674     # 13. run beam search
# -> 1675     return self.beam_search(
#    1676         input_ids,
#    1677         beam_scorer,
#    1678         logits_processor=logits_processor,
#    1679         stopping_criteria=stopping_criteria,
#    1680         pad_token_id=generation_config.pad_token_id,
#    1681         eos_token_id=generation_config.eos_token_id,
#    1682         output_scores=generation_config.output_scores,
#    1683         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1684         synced_gpus=synced_gpus,
#    1685         **model_kwargs,
#    1686     )
#    1688 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1689     # 11. prepare logits warper
#    1690     logits_warper = self._get_logits_warper(generation_config)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\generation\utils.py:3014, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    3010         break
#    3012 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
# -> 3014 outputs = self(
#    3015     **model_inputs,
#    3016     return_dict=True,
#    3017     output_attentions=output_attentions,
#    3018     output_hidden_states=output_hidden_states,
#    3019 )
#    3021 if synced_gpus and this_peer_finished:
#    3022     cur_len = cur_len + 1
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:1388, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1383     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1384         decoder_input_ids = shift_tokens_right(
#    1385             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1386         )
# -> 1388 outputs = self.model(
#    1389     input_ids,
#    1390     attention_mask=attention_mask,
#    1391     decoder_input_ids=decoder_input_ids,
#    1392     encoder_outputs=encoder_outputs,
#    1393     decoder_attention_mask=decoder_attention_mask,
#    1394     head_mask=head_mask,
#    1395     decoder_head_mask=decoder_head_mask,
#    1396     cross_attn_head_mask=cross_attn_head_mask,
#    1397     past_key_values=past_key_values,
#    1398     inputs_embeds=inputs_embeds,
#    1399     decoder_inputs_embeds=decoder_inputs_embeds,
#    1400     use_cache=use_cache,
#    1401     output_attentions=output_attentions,
#    1402     output_hidden_states=output_hidden_states,
#    1403     return_dict=return_dict,
#    1404 )
#    1406 lm_logits = self.lm_head(outputs[0])
#    1407 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:1274, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1267     encoder_outputs = BaseModelOutput(
#    1268         last_hidden_state=encoder_outputs[0],
#    1269         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1270         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1271     )
#    1273 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1274 decoder_outputs = self.decoder(
#    1275     input_ids=decoder_input_ids,
#    1276     attention_mask=decoder_attention_mask,
#    1277     encoder_hidden_states=encoder_outputs[0],
#    1278     encoder_attention_mask=attention_mask,
#    1279     head_mask=decoder_head_mask,
#    1280     cross_attn_head_mask=cross_attn_head_mask,
#    1281     past_key_values=past_key_values,
#    1282     inputs_embeds=decoder_inputs_embeds,
#    1283     use_cache=use_cache,
#    1284     output_attentions=output_attentions,
#    1285     output_hidden_states=output_hidden_states,
#    1286     return_dict=return_dict,
#    1287 )
#    1289 if not return_dict:
#    1290     return decoder_outputs + encoder_outputs
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:1132, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1121     layer_outputs = torch.utils.checkpoint.checkpoint(
#    1122         create_custom_forward(decoder_layer),
#    1123         hidden_states,
#    (...)
#    1129         None,
#    1130     )
#    1131 else:
# -> 1132     layer_outputs = decoder_layer(
#    1133         hidden_states,
#    1134         attention_mask=attention_mask,
#    1135         encoder_hidden_states=encoder_hidden_states,
#    1136         encoder_attention_mask=encoder_attention_mask,
#    1137         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1138         cross_attn_layer_head_mask=(
#    1139             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1140         ),
#    1141         past_key_value=past_key_value,
#    1142         output_attentions=output_attentions,
#    1143         use_cache=use_cache,
#    1144     )
#    1145 hidden_states = layer_outputs[0]
#    1147 if use_cache:
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:465, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     463 hidden_states = self.activation_fn(self.fc1(hidden_states))
#     464 hidden_states = nn.functional.dropout(hidden_states, p=self.activation_dropout, training=self.training)
# --> 465 hidden_states = self.fc2(hidden_states)
#     466 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     467 hidden_states = residual + hidden_states
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import string
import re
from transformers import pipeline, AutoTokenizer

# Load the summarization model and tokenizer
model_name = "facebook/bart-large-cnn"
summarizer = pipeline("summarization", model=model_name, framework="pt")
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Function to clean text
def clean_text(text):
    # Remove punctuation using string.punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Remove extra spaces
    text = re.sub(' +', ' ', text)  # Replace multiple spaces with a single space
    
    # Remove any remaining symbols (e.g., #, $, %, &)
    text = re.sub(r'[^A-Za-z0-9\s]', '', text)
    
    # Strip leading/trailing spaces
    text = text.strip()
    
    return text

# Load the original CSV file
df = pd.read_csv("lyrics_CSV.csv")  # Replace 'lyrics_CSV.csv' with your CSV file path

# Define the summarization function
def summarize_lyrics(lyrics, song_name):
    if pd.isna(lyrics) or not lyrics.strip():  # Check for NaN or empty lyrics
        print(f"{song_name} lyrics are empty or NaN, added directly.")
        return lyrics
    
    # Clean the lyrics
    cleaned_lyrics = clean_text(lyrics)
    
    # Tokenize the cleaned lyrics
    tokens = tokenizer(cleaned_lyrics, return_tensors='pt', truncation=False)["input_ids"][0]
    token_count = len(tokens)

    # If initial tokens are less than 512, return the original cleaned lyrics
    if token_count < 512:
        print(f"{song_name} lyrics are less than 512 tokens, added directly.")
        return cleaned_lyrics
    
    # If token count exceeds 1024, truncate before summarization
    if token_count > 1024:
        tokens = tokens[:1024]  # Keep only the first 1024 tokens
        cleaned_lyrics = tokenizer.decode(tokens, skip_special_tokens=True)
        print(f"{song_name} lyrics truncated to 1024 tokens.")

    # Summarize the cleaned lyrics
    try:
        summary = summarizer(cleaned_lyrics, max_length=512, min_length=0, do_sample=False)
        print(f"{song_name} lyrics summarized")
        return summary[0]['summary_text']
    except Exception as e:
        print(f"Error summarizing {song_name}: {e}")
        return cleaned_lyrics  # Return original cleaned lyrics if there's an error

# Initialize a counter for song names
for idx, row in df.iterrows():
    df.at[idx, 'Summarized_Lyrics'] = summarize_lyrics(row['Lyrics'], row['Song Name'])

# Save the dataframe with summarized lyrics to a new CSV file
df.to_csv("Lyrics_Sum.csv", index=False)
# Out:
# Legacy lyrics summarized
# Token indices sequence length is longer than the specified maximum sequence length for this model (1174 > 1024). Running this sequence through the model will result in indexing errors
# Still Don't Give A Fuck lyrics summarized
# Asshole lyrics truncated to 1024 tokens.
# Asshole lyrics summarized
# Cum On Everybody lyrics summarized
# Token indices sequence length is longer than the specified maximum sequence length for this model (1025 > 1024). Running this sequence through the model will result in indexing errors
# W.T.P. lyrics summarized
# Beautiful lyrics truncated to 1024 tokens.
# Error summarizing Beautiful: index out of range in self
# Medicine Ball lyrics summarized
# My Mom lyrics summarized
# So Far... lyrics truncated to 1024 tokens.
# Error summarizing So Far...: index out of range in self
# Yellow Brick Road lyrics truncated to 1024 tokens.
# Error summarizing Yellow Brick Road: index out of range in self
# When I'm Gone lyrics summarized
# Rhyme Or Reason lyrics summarized
# My Fault lyrics summarized
# Hello lyrics summarized
# Underground lyrics truncated to 1024 tokens.
# Error summarizing Underground: index out of range in self
# Hell Breaks Loose lyrics summarized
# Stan lyrics truncated to 1024 tokens.
# Error summarizing Stan: index out of range in self
# Cleanin Out My Closet lyrics summarized
# We As Americans lyrics summarized
# Almost Famous lyrics truncated to 1024 tokens.
# Error summarizing Almost Famous: index out of range in self
# Just Lose It lyrics summarized
# Trapped lyrics are less than 512 tokens, added directly.
# When The Music Stops lyrics truncated to 1024 tokens.
# Error summarizing When The Music Stops: index out of range in self
# Drug Ballad lyrics truncated to 1024 tokens.
# Error summarizing Drug Ballad: index out of range in self
# My Dad's Gone Crazy lyrics summarized
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 65
#      63 # Initialize a counter for song names
#      64 for idx, row in df.iterrows():
# ---> 65     df.at[idx, 'Summarized_Lyrics'] = summarize_lyrics(row['Lyrics'], row['Song Name'])
#      67 # Save the dataframe with summarized lyrics to a new CSV file
#      68 df.to_csv("Lyrics_Sum.csv", index=False)
#
# Cell In[5], line 56, in summarize_lyrics(lyrics, song_name)
#      54 # Summarize the cleaned lyrics
#      55 try:
# ---> 56     summary = summarizer(cleaned_lyrics, max_length=512, min_length=0, do_sample=False)
#      57     print(f"{song_name} lyrics summarized")
#      58     return summary[0]['summary_text']
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\text2text_generation.py:265, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     241 def __call__(self, *args, **kwargs):
#     242     r"""
#     243     Summarize the text(s) given as inputs.
#     244
#    (...)
#     263           ids of the summary.
#     264     """
# --> 265     return super().__call__(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\text2text_generation.py:165, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     136 def __call__(self, *args, **kwargs):
#     137     r"""
#     138     Generate the output text(s) using text(s) given as inputs.
#     139
#    (...)
#     162           ids of the generated text.
#     163     """
# --> 165     result = super().__call__(*args, **kwargs)
#     166     if (
#     167         isinstance(args[0], list)
#     168         and all(isinstance(el, str) for el in args[0])
#     169         and all(len(res) == 1 for res in result)
#     170     ):
#     171         return [res[0] for res in result]
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1129, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1121     return next(
#    1122         iter(
#    1123             self.get_iterator(
#    (...)
#    1126         )
#    1127     )
#    1128 else:
# -> 1129     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1136, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1134 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1135     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1136     model_outputs = self.forward(model_inputs, **forward_params)
#    1137     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1138     return outputs
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1035, in Pipeline.forward(self, model_inputs, **forward_params)
#    1033     with inference_context():
#    1034         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1035         model_outputs = self._forward(model_inputs, **forward_params)
#    1036         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1037 else:
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\pipelines\text2text_generation.py:187, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     185 generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     186 self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 187 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     188 out_b = output_ids.shape[0]
#     189 if self.framework == "pt":
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\generation\utils.py:1675, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1668     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1669         input_ids=input_ids,
#    1670         expand_size=generation_config.num_beams,
#    1671         is_encoder_decoder=self.config.is_encoder_decoder,
#    1672         **model_kwargs,
#    1673     )
#    1674     # 13. run beam search
# -> 1675     return self.beam_search(
#    1676         input_ids,
#    1677         beam_scorer,
#    1678         logits_processor=logits_processor,
#    1679         stopping_criteria=stopping_criteria,
#    1680         pad_token_id=generation_config.pad_token_id,
#    1681         eos_token_id=generation_config.eos_token_id,
#    1682         output_scores=generation_config.output_scores,
#    1683         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1684         synced_gpus=synced_gpus,
#    1685         **model_kwargs,
#    1686     )
#    1688 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1689     # 11. prepare logits warper
#    1690     logits_warper = self._get_logits_warper(generation_config)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\generation\utils.py:3014, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    3010         break
#    3012 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
# -> 3014 outputs = self(
#    3015     **model_inputs,
#    3016     return_dict=True,
#    3017     output_attentions=output_attentions,
#    3018     output_hidden_states=output_hidden_states,
#    3019 )
#    3021 if synced_gpus and this_peer_finished:
#    3022     cur_len = cur_len + 1
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:1388, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1383     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1384         decoder_input_ids = shift_tokens_right(
#    1385             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1386         )
# -> 1388 outputs = self.model(
#    1389     input_ids,
#    1390     attention_mask=attention_mask,
#    1391     decoder_input_ids=decoder_input_ids,
#    1392     encoder_outputs=encoder_outputs,
#    1393     decoder_attention_mask=decoder_attention_mask,
#    1394     head_mask=head_mask,
#    1395     decoder_head_mask=decoder_head_mask,
#    1396     cross_attn_head_mask=cross_attn_head_mask,
#    1397     past_key_values=past_key_values,
#    1398     inputs_embeds=inputs_embeds,
#    1399     decoder_inputs_embeds=decoder_inputs_embeds,
#    1400     use_cache=use_cache,
#    1401     output_attentions=output_attentions,
#    1402     output_hidden_states=output_hidden_states,
#    1403     return_dict=return_dict,
#    1404 )
#    1406 lm_logits = self.lm_head(outputs[0])
#    1407 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:1274, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1267     encoder_outputs = BaseModelOutput(
#    1268         last_hidden_state=encoder_outputs[0],
#    1269         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1270         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1271     )
#    1273 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1274 decoder_outputs = self.decoder(
#    1275     input_ids=decoder_input_ids,
#    1276     attention_mask=decoder_attention_mask,
#    1277     encoder_hidden_states=encoder_outputs[0],
#    1278     encoder_attention_mask=attention_mask,
#    1279     head_mask=decoder_head_mask,
#    1280     cross_attn_head_mask=cross_attn_head_mask,
#    1281     past_key_values=past_key_values,
#    1282     inputs_embeds=decoder_inputs_embeds,
#    1283     use_cache=use_cache,
#    1284     output_attentions=output_attentions,
#    1285     output_hidden_states=output_hidden_states,
#    1286     return_dict=return_dict,
#    1287 )
#    1289 if not return_dict:
#    1290     return decoder_outputs + encoder_outputs
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:1132, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1121     layer_outputs = torch.utils.checkpoint.checkpoint(
#    1122         create_custom_forward(decoder_layer),
#    1123         hidden_states,
#    (...)
#    1129         None,
#    1130     )
#    1131 else:
# -> 1132     layer_outputs = decoder_layer(
#    1133         hidden_states,
#    1134         attention_mask=attention_mask,
#    1135         encoder_hidden_states=encoder_hidden_states,
#    1136         encoder_attention_mask=encoder_attention_mask,
#    1137         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1138         cross_attn_layer_head_mask=(
#    1139             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1140         ),
#    1141         past_key_value=past_key_value,
#    1142         output_attentions=output_attentions,
#    1143         use_cache=use_cache,
#    1144     )
#    1145 hidden_states = layer_outputs[0]
#    1147 if use_cache:
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:446, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     444 # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     445 cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 446 hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     447     hidden_states=hidden_states,
#     448     key_value_states=encoder_hidden_states,
#     449     attention_mask=encoder_attention_mask,
#     450     layer_head_mask=cross_attn_layer_head_mask,
#     451     past_key_value=cross_attn_past_key_value,
#     452     output_attentions=output_attentions,
#     453 )
#     454 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     455 hidden_states = residual + hidden_states
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\models\bart\modeling_bart.py:276, in BartAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     272     attn_weights_reshaped = None
#     274 attn_probs = nn.functional.dropout(attn_weights, p=self.dropout, training=self.training)
# --> 276 attn_output = torch.bmm(attn_probs, value_states)
#     278 if attn_output.size() != (bsz * self.num_heads, tgt_len, self.head_dim):
#     279     raise ValueError(
#     280         f"`attn_output` should be of size {(bsz * self.num_heads, tgt_len, self.head_dim)}, but is"
#     281         f" {attn_output.size()}"
#     282     )
#
# KeyboardInterrupt:

# %%
import pandas as pd
from transformers import BartTokenizer, BartForConditionalGeneration
import torch

# Load BART model and tokenizer
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')

# Load the CSV file
df = pd.read_csv('lyrics_CSV.csv')

# Initialize lists to store processed data
artist_names = []
song_names = []
sum_lyrics = []

# Function to get the token count of the lyrics
def get_token_count(text):
    tokens = tokenizer.encode(text, return_tensors="pt")
    return tokens.shape[1]

# Function to summarize lyrics
def summarize_lyrics(lyrics):
    inputs = tokenizer.encode(lyrics, return_tensors="pt", max_length=1024, truncation=True)
    summary_ids = model.generate(inputs, max_length=512, min_length=50, length_penalty=2.0, num_beams=4, early_stopping=True)
    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    artist = row['Artist Name']
    song = row['Song Name']
    lyrics = row['Lyrics']
    
    # Get token count of the lyrics
    token_count = get_token_count(lyrics)
    
    if token_count < 512:
        # If the lyrics have less than 512 tokens, keep it as is
        summary = lyrics
        method = "as it is"
    elif token_count > 1024:
        # If the lyrics have more than 1024 tokens, truncate to 1024 and then summarize
        truncated_lyrics = tokenizer.decode(tokenizer.encode(lyrics, max_length=1024, truncation=True))
        summary = summarize_lyrics(truncated_lyrics)
        method = "truncate"
    else:
        # If the lyrics have between 512 and 1024 tokens, summarize directly
        summary = summarize_lyrics(lyrics)
        method = "through model"
    
    # Append the processed data to lists
    artist_names.append(artist)
    song_names.append(song)
    sum_lyrics.append(summary)
    
    # Print the processing status
    print(f"{song} summarized with {method}")

# Create a new DataFrame for summarized lyrics
sum_df = pd.DataFrame({
    'Artist Name': artist_names,
    'Song Name': song_names,
    'Sum Lyrics': sum_lyrics
})

# Save the summarized data to a new CSV file
sum_df.to_csv('Sum_lyrics.csv', index=False)

print("Summarization process completed and saved to Sum_lyrics.csv")
# Out:
# c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# WARNING:tensorflow:From c:\Users\PhnaeendraAdmin\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Legacy summarized with through model
# Token indices sequence length is longer than the specified maximum sequence length for this model (1293 > 1024). Running this sequence through the model will result in indexing errors
# Still Don't Give A Fuck summarized with through model
# Asshole summarized with truncate
# Cum On Everybody summarized with through model
# W.T.P. summarized with truncate
# Beautiful summarized with truncate
# Medicine Ball summarized with through model
# My Mom summarized with truncate
# So Far... summarized with truncate
# Yellow Brick Road summarized with truncate
# When I'm Gone summarized with truncate
# Rhyme Or Reason summarized with truncate
# My Fault summarized with through model
# Hello summarized with through model
# Underground summarized with truncate
# Hell Breaks Loose summarized with through model
# Stan summarized with truncate
# Cleanin Out My Closet summarized with through model
# We As Americans summarized with through model
# Almost Famous summarized with truncate
# Just Lose It summarized with through model
# Trapped summarized with as it is
# When The Music Stops summarized with truncate
# Drug Ballad summarized with truncate
# My Dad's Gone Crazy summarized with truncate
# Desperation summarized with through model
# Bad Guy summarized with truncate
# Sing For The Moment summarized with truncate
# Puke summarized with through model
# Square Dance summarized with truncate
# Marshall Mathers summarized with truncate
# Drips summarized with truncate
# Criminal summarized with truncate
# I'm Shady summarized with through model
# You Don't Know summarized with through model
# Evil Deeds summarized with truncate
# 3 A.M. summarized with truncate
# Ricky Ticky Toc summarized with through model
# Buffalo Bill summarized with through model
# Say Goodbye Hollywood summarized with truncate
# Bitch Please II summarized with truncate
# Who Knew summarized with truncate
# Love The Way You Lie summarized with through model
# Forever summarized with truncate
# Untitled summarized with through model
# Old Time's Sake summarized with truncate
# Music Box summarized with through model
# Fack summarized with through model
# Crack A Bottle summarized with truncate
# Love Game summarized with truncate
# Seduction summarized with truncate
# White America summarized with truncate
# Role Model summarized with through model
# Space Bound summarized with through model
# Bagpipes From Baghdad summarized with truncate
# Rap God summarized with truncate
# Big Weenie summarized with truncate
# Not Afraid summarized with truncate
# Be Like You summarized with as it is
# Barcelona summarized with as it is
# Bibia Be Ye Ye summarized with through model
# Cold Coffee summarized with as it is
# Save Myself summarized with as it is
# The Man summarized with through model
# All Of The Stars summarized with as it is
# Goodbye To You summarized with truncate
# UNI summarized with through model
# I'm A Mess summarized with as it is
# Happier summarized with as it is
# Nightmares summarized with through model
# Hearts Don't Break Around Here summarized with as it is
# New Man summarized with through model
# Little Lady summarized with truncate
# Fall summarized with as it is
# Give Me Love summarized with through model
# Nancy Mulligan summarized with as it is
# One summarized with as it is
# Perfect summarized with as it is
# Photograph summarized with as it is
# Sing summarized with through model
# Castle On The Hill summarized with as it is
# Galway Girl summarized with through model
# Grade 8 summarized with as it is
# Homeless summarized with through model
# New York summarized with as it is
# Fire Alarms summarized with as it is
# Afire Love summarized with as it is
# Dive summarized with as it is
# Shape Of You summarized with through model
# Let It Out summarized with as it is
# Drunk summarized with as it is
# Sofa summarized with as it is
# Sunburn summarized with as it is
# I See Fire summarized with as it is
# You summarized with through model
# You Need Me, I Don't Need You summarized with truncate
# Drown Me Out summarized with through model
# So summarized with as it is
# Lego House summarized with through model
# Thinking Out Loud summarized with as it is
# Where We Land summarized with as it is
# Eraser summarized with through model
# Kiss Me summarized with as it is
# Runaway summarized with as it is
# Tenerife Sea summarized with as it is
# What Do I Know? summarized with through model
# Family summarized with through model
# The City summarized with as it is
# English Rose summarized with as it is
# The A Team summarized with as it is
# Lately summarized with through model
# Supermarket Flowers summarized with as it is
# Touch And Go summarized with as it is
# Tell Me Why summarized with as it is
# Style summarized with as it is
# We Are Never Ever Getting Back Together summarized with as it is
# State Of Grace summarized with as it is
# The Story Of Us summarized with through model
# Stay Beautiful summarized with as it is
# Back To December summarized with as it is
# The Lucky One summarized with as it is
# I Almost Do summarized with as it is
# The Last Time summarized with as it is
# You Belong With Me summarized with as it is
# Wildest Dreams summarized with as it is
# Tied Together With A Smile summarized with as it is
# Should've Said No summarized with as it is
# Change summarized with as it is
# Better Than Revenge summarized with through model
# I Knew You Were Trouble summarized with as it is
# Untouchable summarized with as it is
# Never Grow Up summarized with as it is
# Superstar summarized with as it is
# The Other Side Of The Door summarized with as it is
# Last Kiss summarized with as it is
# Cold As You summarized with as it is
# White Horse summarized with as it is
# Blank Space summarized with through model
# Hey Stephen summarized with as it is
# Fearless summarized with as it is
# Picture To Burn summarized with as it is
# Love Story summarized with as it is
# Long Live summarized with as it is
# Mine summarized with as it is
# Begin Again summarized with as it is
# Welcome To New York summarized with as it is
# Jump Then Fall summarized with as it is
# A Place In This World summarized with as it is
# Holy Ground summarized with as it is
# Bette Davis Eyes summarized with as it is
# You're Not Sorry summarized with as it is
# Everything Has Changed summarized with as it is
# This Love summarized with as it is
# Sad Beautiful Tragic summarized with as it is
# The Outside summarized with as it is
# Fifteen summarized with as it is
# I Want You Back summarized with as it is
# Starlight summarized with as it is
# Stay summarized with as it is
# Fading summarized with as it is
# Birthday Cake summarized with as it is
# Breakin' Dishes summarized with through model
# There's A Thug In My Life summarized with through model
# Right Now summarized with as it is
# Shut Up And Drive summarized with through model
# What's My Name? summarized with through model
# Get It Over With summarized with as it is
# A Girl Like Me summarized with through model
# Take A Bow summarized with as it is
# Rush summarized with through model
# Good Girl Gone Bad summarized with as it is
# Willing To Wait summarized with as it is
# Farewell summarized with as it is
# That La, La, La summarized with through model
# Kisses Don't Lie summarized with through model
# G4L summarized with as it is
# Love Without Tragedy / Mother Mary summarized with through model
# The Last Song summarized with as it is
# Rude Boy summarized with through model
# You Da One summarized with through model
# Lemme Get That summarized with through model
# Here I Go Again summarized with through model
# Rehab summarized with through model
# Pon De Replay summarized with through model
# We Found Love summarized with as it is
# Final Goodbye summarized with as it is
# Lost In Paradise summarized with as it is
# Numb summarized with through model
# Mad House summarized with as it is
# Wait Your Turn summarized with through model
# Pour It Up summarized with as it is
# Cold Case Love summarized with as it is
# Music Of The Sun summarized with through model
# We All Want Love summarized with as it is
# Complicated summarized with as it is
# Drunk On Love summarized with as it is
# Russian Roulette summarized with as it is
# Question Existing summarized with as it is
# Photographs summarized with through model
# Loveeeeeee Song summarized with as it is
# Stupid In Love summarized with as it is
# Rockstar 101 summarized with through model
# The Last Time summarized with as it is
# Fire Bomb summarized with as it is
# Jump summarized with through model
# Raining Men summarized with through model
# Disturbia summarized with through model
# Selfish Girl summarized with through model
# Talk That Talk summarized with through model
# Where Have You Been summarized with as it is
# Say It summarized with through model
# Unfaithful summarized with as it is
# Fool In Love summarized with as it is
# Red Lipstick summarized with as it is
# Umbrella summarized with through model
# Dem Haters summarized with through model
# Push Up On Me summarized with through model
# Hard summarized with through model
# Diamonds summarized with as it is
# We Ride summarized with through model
# Hate That I Love You summarized with as it is
# Do Ya Thang summarized with through model
# A Million Miles Away summarized with as it is
# Now I Know summarized with as it is
# Sell Me Candy summarized with as it is
# Te Amo summarized with as it is
# California King Bed summarized with as it is
# Don't Stop The Music summarized with through model
# Skin summarized with through model
# No Love Allowed summarized with as it is
# Man Down summarized with through model
# Crazy Little Thing Called Love summarized with through model
# S&M summarized with through model
# Break It Off summarized with through model
# If It's Lovin' That You Want summarized with through model
# Watch N' Learn summarized with through model
# Roc Me Out summarized with as it is
# What Now summarized with as it is
# Let Me summarized with through model
# Be My Baby summarized with as it is
# Break Free summarized with as it is
# Only 1 summarized with as it is
# Baby I summarized with through model
# Hands On Me summarized with through model
# My Everything summarized with as it is
# Love Me Harder summarized with through model
# Daydreamin' summarized with as it is
# Piano summarized with through model
# Best Mistake summarized with through model
# Break Your Heart Right Back summarized with through model
# Better Left Unsaid summarized with as it is
# Tattooed Heart summarized with as it is
# Lovin' It summarized with through model
# You'll Never Know summarized with through model
# One Last Time summarized with as it is
# Why Try summarized with through model
# Intro summarized with as it is
# You Don't Know Me summarized with through model
# Just A Little Bit Of Your Heart summarized with as it is
# Problem summarized with through model
# Honeymoon Avenue summarized with through model
# Fix You summarized with as it is
# Spies summarized with as it is
# Lovers In Japan / Reign Of Love summarized with as it is
# Daylight summarized with as it is
# Hurts Like Heaven summarized with as it is
# Miracles summarized with as it is
# Prospekt's March / Poppyfields summarized with as it is
# Kaleidoscope summarized with as it is
# A L I E N S summarized with as it is
# Easy To Please summarized with as it is
# Charlie Brown summarized with as it is
# Low summarized with as it is
# Twisted Logic summarized with as it is
# Paradise summarized with through model
# True Love summarized with as it is
# Talk summarized with as it is
# Hymn For The Weekend summarized with as it is
# One I Love summarized with as it is
# Ink summarized with as it is
# Hypnotised summarized with as it is
# A Rush Of Blood To The Head summarized with as it is
# A Message summarized with as it is
# Adventure Of A Lifetime summarized with as it is
# O summarized with as it is
# Don't Panic summarized with as it is
# Viva La Vida summarized with as it is
# The Scientist summarized with as it is
# Always In My Head summarized with as it is
# Parachutes summarized with as it is
# Army Of One summarized with as it is
# Moses summarized with as it is
# U.F.O. summarized with as it is
# Cemeteries Of London summarized with as it is
# Only Superstition summarized with as it is
# Rainy Day summarized with as it is
# Magic summarized with as it is
# Violet Hill summarized with as it is
# A Head Full Of Dreams summarized with as it is
# Lost! summarized with as it is
# All I Can Think About Is You summarized with as it is
# Green Eyes summarized with as it is
# Now My Feet Won't Touch The Ground summarized with as it is
# Speed Of Sound summarized with as it is
# God Put A Smile Upon Your Face summarized with as it is
# The World Turned Upside Down summarized with as it is
# Oceans summarized with as it is
# Fun summarized with as it is
# Up In Flames summarized with as it is
# Everything's Not Lost summarized with as it is
# Midnight summarized with as it is
# What If? summarized with as it is
# Swallowed In The Sea summarized with as it is
# A Sky Full Of Stars summarized with as it is
# Us Against The World summarized with as it is
# Life Is For Living summarized with as it is
# Major Minus summarized with as it is
# Clocks summarized with as it is
# Colour Spectrum summarized with as it is
# 42 summarized with as it is
# Strawberry Swing summarized with as it is
# In My Place summarized with as it is
# Death And All His Friends summarized with as it is
# Princess Of China summarized with as it is
# White Shadows summarized with as it is
# Don't Let It Break Your Heart summarized with as it is
# Trouble summarized with as it is
# X&Y summarized with as it is
# Every Teardrop Is A Waterfall summarized with as it is
# Pour Me summarized with as it is
# Up With The Birds summarized with as it is
# Politik summarized with as it is
# High Speed summarized with as it is
# Life In Technicolor II summarized with as it is
# Amsterdam summarized with as it is
# Yes summarized with as it is
# Another's Arms summarized with as it is
# Amazing Day summarized with as it is
# Til Kingdom Come summarized with as it is
# Everglow summarized with as it is
# Up&Up summarized with through model
# Yellow summarized with as it is
# Off To The Races summarized with through model
# Diet Mountain Dew summarized with through model
# This Is What Makes Us Girls summarized with through model
# Million Dollar Man summarized with as it is
# Don't Let Me Be Misunderstood summarized with as it is
# The Blackest Day summarized with as it is
# Gods & Monsters summarized with as it is
# Fucked My Way Up To The Top summarized with as it is
# Pretty When You Cry summarized with as it is
# Dark Paradise summarized with through model
# Cruel World summarized with as it is
# Religion summarized with as it is
# Video Games summarized with as it is
# Swan Song summarized with as it is
# Terrence Loves You summarized with as it is
# Freak summarized with as it is
# God Knows I Tried summarized with as it is
# Money Power Glory summarized with as it is
# Music To Watch Boys To summarized with as it is
# Blue Jeans summarized with as it is
# National Anthem summarized with through model
# Body Electric summarized with as it is
# Born To Die summarized with through model
# Old Money summarized with as it is
# Bel Air summarized with as it is
# Honeymoon summarized with as it is
# 24 summarized with as it is
# Radio summarized with as it is
# The Other Woman summarized with as it is
# Summertime Sadness summarized with as it is
# Yayo summarized with as it is
# Carmen summarized with as it is
# Sad Girl summarized with as it is
# High By The Beach summarized with as it is
# Blue Velvet summarized with as it is
# Ride summarized with as it is
# Art Deco summarized with as it is
# American summarized with as it is
# West Coast summarized with as it is
# Salvatore summarized with as it is
# Must Get Out summarized with as it is
# Tangled summarized with as it is
# In Your Pocket summarized with through model
# This Love summarized with as it is
# Highway To Hell summarized with as it is
# Don't Know Nothing summarized with as it is
# Nothing Lasts Forever summarized with as it is
# Coming Back For You summarized with as it is
# Moves Like Jagger summarized with through model
# Unkiss Me summarized with as it is
# New Love summarized with as it is
# Not Falling Apart summarized with as it is
# Feelings summarized with as it is
# Miss You, Love You summarized with as it is
# I Can't Lie summarized with as it is
# Stutter summarized with as it is
# Little Of Your Time summarized with as it is
# Infatuation summarized with as it is
# Back At Your Door summarized with as it is
# Sex And Candy summarized with as it is
# Wake Up Call summarized with through model
# Losing My Mind summarized with as it is
# Shiver summarized with as it is
# Hands All Over summarized with as it is
# If I Never See Your Face Again summarized with as it is
# Harder To Breathe summarized with as it is
# It Was Always You summarized with as it is
# Maps summarized with as it is
# Runaway summarized with as it is
# Secret summarized with as it is
# Can't Stop summarized with as it is
# Story summarized with as it is
# Won't Go Home Without You summarized with as it is
# Shoot Love summarized with as it is
# Sugar summarized with through model
# Give A Little More summarized with as it is
# My Heart Is Open summarized with as it is
# Not Coming Home summarized with as it is
# Makes Me Wonder summarized with as it is
# She Will Be Loved summarized with as it is
# Sweetest Goodbye summarized with as it is
# Lost Stars summarized with as it is
# The Sun summarized with as it is
# Leaving California summarized with as it is
# Misery summarized with as it is
# Never Gonna Leave This Bed summarized with as it is
# If I Fell summarized with as it is
# Better That We Break summarized with as it is
# Sunday Morning summarized with as it is
# Through With You summarized with as it is
# Kiwi summarized with as it is
# Goodnight Goodnight summarized with as it is
# Until You're Over Me summarized with as it is
# Get Back In My Life summarized with as it is
# Just A Feeling summarized with as it is
# Animals summarized with through model
# How summarized with as it is
# Will You Be There summarized with as it is
# Earth Song summarized with through model
# Loving You summarized with as it is
# All The Things You Are summarized with as it is
# We've Had Enough summarized with through model
# Get On The Floor summarized with through model
# People Make The World Go Round summarized with as it is
# Just A Little Bit Of You summarized with as it is
# Heal The World summarized with through model
# My Girl summarized with as it is
# 2 Bad summarized with through model
# It's The Falling In Love summarized with through model
# Dangerous summarized with through model
# Girlfriend summarized with as it is
# You Can Cry On My Shoulder summarized with as it is
# Don't Walk Away summarized with as it is
# You Are There summarized with as it is
# Everybody's Somebody's Fool summarized with as it is
# With A Child's Heart summarized with as it is
# Rock With You summarized with as it is
# Don't Stop 'Til You Get Enough summarized with through model
# Beautiful Girl summarized with as it is
# Can't Let Her Get Away summarized with as it is
# Love Never Felt So Good summarized with as it is
# Beat It summarized with through model
# You Rock My World summarized with through model
# Ghosts summarized with through model
# You Can't Win summarized with as it is
# Leave Me Alone summarized with through model
# Scared Of The Moon summarized with as it is
# Black Or White summarized with through model
# Dear Michael summarized with as it is
# We Are Here To Change The World summarized with as it is
# I Just Can't Stop Loving You summarized with through model
# She Drives Me Wild summarized with as it is
# You've Really Got A Hold On Me summarized with as it is
# Too Young summarized with as it is
# Carousel summarized with as it is
# Monster summarized with through model
# Blood On The Dance Floor summarized with through model
# In The Back summarized with as it is
# Chicago summarized with through model
# The Lost Children summarized with as it is
# Fly Away summarized with as it is
# Touch The One You Love summarized with as it is
# I Can't Help It summarized with as it is
# Who Is It summarized with through model
# Wings Of My Love summarized with as it is
# Scream summarized with through model
# Heartbreaker summarized with through model
# Little Susie summarized with as it is
# She's Out Of My Life summarized with as it is
# Heaven Can Wait summarized with through model
# They Don't Care About Us summarized with through model
# D.S. summarized with through model
# Fall Again summarized with as it is
# Ain't No Sunshine summarized with through model
# You Are Not Alone summarized with as it is
# Jam summarized with through model
# Streetwalker summarized with through model
# You Are My Life summarized with through model
# Johnny Raven summarized with as it is
# Take Me Back summarized with as it is
# One Day In Your Life summarized with as it is
# Xscape summarized with through model
# Girl You're So Together summarized with as it is
# We're Almost There summarized with as it is
# Dirty Diana summarized with through model
# Hollywood Tonight summarized with as it is
# Smooth Criminal summarized with through model
# This Time Around summarized with through model
# On The Line summarized with as it is
# Keep The Faith summarized with through model
# Superfly Sister summarized with through model
# Happy summarized with as it is
# In The Closet summarized with through model
# The Way You Make Me Feel summarized with through model
# Another Part Of Me summarized with as it is
# Speed Demon summarized with as it is
# Money summarized with through model
# Speechless summarized with as it is
# Threatened summarized with through model
# Working Day And Night summarized with through model
# 2000 Watts summarized with as it is
# To Make My Father Proud summarized with as it is
# Blue Gangsta summarized with through model
# Human Nature summarized with through model
# Whatever Happens summarized with as it is
# Why You Wanna Trip On Me summarized with as it is
# Much Too Soon summarized with as it is
# Just Good Friends summarized with through model
# Stranger In Moscow summarized with through model
# Call On Me summarized with as it is
# Monkey Business summarized with through model
# Childhood summarized with as it is
# Is It Scary? summarized with through model
# Man In The Mirror summarized with through model
# Give In To Me summarized with as it is
# HIStory summarized with as it is
# Thriller summarized with through model
# I Wanna Be Where You Are summarized with as it is
# We've Got Forever summarized with as it is
# Farewell My Summer Love summarized with as it is
# Got To Be There summarized with as it is
# Butterflies summarized with through model
# Someone Put Your Hand Out summarized with as it is
# Liberian Girl summarized with as it is
# Smile summarized with as it is
# Wanna Be Startin' Somethin' summarized with truncate
# Best Of Joy summarized with as it is
# Keep Your Head Up summarized with through model
# A Place With No Name summarized with through model
# Up Again summarized with as it is
# What Goes Around Comes Around summarized with as it is
# Melodie summarized with as it is
# Break Of Dawn summarized with through model
# I'll Come Home To You summarized with as it is
# In Our Small Way summarized with as it is
# Behind The Mask summarized with through model
# Girl Don't Take Your Love From Me summarized with as it is
# Ben summarized with as it is
# Cheater summarized with through model
# Dapper Dan summarized with as it is
# One More Chance summarized with as it is
# Come Together summarized with through model
# Invincible summarized with through model
# Off The Wall summarized with through model
# The Lady In My Life summarized with through model
# You've Got A Friend summarized with as it is
# Do You Know Where Your Children Are summarized with through model
# Someone In The Dark summarized with as it is
# Euphoria summarized with as it is
# Love Is Here And Now You're Gone summarized with as it is
# Billie Jean summarized with through model
# Baby Be Mine summarized with through model
# Breaking News summarized with as it is
# The Girl Is Mine summarized with through model
# Privacy summarized with through model
# Cry summarized with as it is
# Hold My Hand summarized with through model
# Remember The Time summarized with through model
# Morphine summarized with through model
# Rockin' Robin summarized with as it is
# Gone Too Soon summarized with as it is
# This Is It summarized with as it is
# Don't Let It Get You Down summarized with as it is
# Bad summarized with through model
# Doggin' Around summarized with as it is
# We've Got A Good Thing Going summarized with as it is
# Cinderella Stay Awhile summarized with as it is
# The Way You Love Me summarized with as it is
# Morning Glow summarized with as it is
# Slave To The Rhythm summarized with as it is
# Tabloid Junkie summarized with through model
# Unbreakable summarized with truncate
# Shoo-Be-Doo-Be-Doo-Da-Day summarized with as it is
# Hey Angel summarized with as it is
# One Thing summarized with as it is
# Wolves summarized with through model
# Why Don't We Go There summarized with as it is
# I Want summarized with as it is
# Gotta Be You summarized with as it is
# Half A Heart summarized with as it is
# Little Things summarized with as it is
# End Of The Day summarized with as it is
# Through The Dark summarized with as it is
# Drag Me Down summarized with as it is
# Still The One summarized with as it is
# Over Again summarized with as it is
# Perfect summarized with through model
# What A Feeling summarized with as it is
# Temporary Fix summarized with as it is
# Diana summarized with as it is
# Loved You First summarized with as it is
# Fool's Gold summarized with as it is
# Best Song Ever summarized with as it is
# Change My Mind summarized with as it is
# Right Now summarized with as it is
# I Wish summarized with as it is
# Ready To Run summarized with as it is
# More Than This summarized with as it is
# Love You Goodbye summarized with as it is
# Story Of My Life summarized with as it is
# Kiss You summarized with as it is
# Better Than Words summarized with as it is
# Does He Know? summarized with as it is
# No Control summarized with as it is
# You & I summarized with as it is
# Little White Lies summarized with as it is
# Never Enough summarized with as it is
# Walking In The Wind summarized with as it is
# Live While We're Young summarized with through model
# Stockholm Syndrome summarized with as it is
# Midnight Memories summarized with as it is
# Girl Almighty summarized with as it is
# Little Black Dress summarized with as it is
# Don't Forget Where You Belong summarized with as it is
# Where Do Broken Hearts Go? summarized with as it is
# I Would summarized with through model
# I Want To Write You A Song summarized with as it is
# Night Changes summarized with as it is
# Tell Me A Lie summarized with as it is
# Happily summarized with as it is
# Back For You summarized with as it is
# Last First Kiss summarized with as it is
# Save You Tonight summarized with as it is
# Spaces summarized with as it is
# Strong summarized with as it is
# Olivia summarized with as it is
# She's Not Afraid summarized with as it is
# Heart Attack summarized with through model
# Summer Love summarized with as it is
# Clouds summarized with as it is
# Infinity summarized with as it is
# Taken summarized with as it is
# Something Great summarized with as it is
# Everything About You summarized with through model
# C'mon, C'mon summarized with as it is
# Stole My Heart summarized with as it is
# A.M. summarized with as it is
# Steal My Girl summarized with as it is
# History summarized with as it is
# They Don't Know About Us summarized with through model
# Nobody Compares summarized with through model
# 18 summarized with as it is
# Rock Me summarized with as it is
# What Makes You Beautiful summarized with through model
# Same Mistakes summarized with as it is
# If I Could Fly summarized with as it is
# Alive summarized with as it is
# Fireproof summarized with as it is
# Up All Night summarized with through model
# Long Way Down summarized with as it is
# Summarization process completed and saved to Sum_lyrics.csv
